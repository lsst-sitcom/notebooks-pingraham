# %%
from lsst.ts import salobj
import asyncio
import logging
from lsst.ts.observatory.control.auxtel.atcs import ATCS
import os
import time
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ts.utils.tai</span> <span style="color: var(--jp-info-color0)">INFO</span>: Update leap second table</pre>
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.ts.utils.tai</span> <span style="color: var(--jp-info-color0)">INFO</span>: current_tai uses the system TAI clock</pre>

# %%
domain = salobj.Domain()

# %%
remote = salobj.Remote(name="Script", domain=domain, index=0)
#remote = salobj.Remote(name="PMD", domain=domain, index=0)
await remote.start_task
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">Script</span> <span style="color: var(--jp-info-color0)">INFO</span>: Read historical data in 0.00 sec</pre>

# %%
def print_logMessage(id_data):
    print(id_data.message)

# %%
remote.evt_logMessage.callback = print_logMessage
# remote.evt_logMessage.callback = None # use this to stop it
# Out:
# [Telescope] delta Alt = -000.001 deg; delta Az = -040.501 deg; delta N1 = -000.000 deg; delta N2 = -000.007 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -036.529 deg; delta N1 = -000.000 deg; delta N2 = -000.021 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -030.572 deg; delta N1 = -000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -026.597 deg; delta N1 = -000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -022.648 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -018.783 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -015.076 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -011.623 deg; delta N1 = -000.000 deg; delta N2 = -000.018 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -007.114 deg; delta N1 = -000.000 deg; delta N2 = -000.007 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -004.677 deg; delta N1 = -000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -002.758 deg; delta N1 = -000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -001.380 deg; delta N1 = +000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -000.521 deg; delta N1 = +000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -000.108 deg; delta N1 = +000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.002 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +002.938 deg
# ATMCS in position: True.
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# imagetype: ENGTEST, skip TCS synchronization.
# ENGTEST 0001 - 0001
# Moving to extra-focal position
# Taking extra-focal image
# imagetype: ENGTEST, skip TCS synchronization.
# ENGTEST 0001 - 0001
# intraImage expId for target: 2022021600271
# extraImage expId for target: 2022021600272
# angle used in cwfs algorithm is -72.57
# Moving hexapod back to zero offset (in-focus) position
# Running source detection
# Source detection completed
# Creating stamp for intra_image donut on centroid [y,x] = [1852,1974] with a side length of 228 pixels
# Creating stamp for intra_image donut on centroid [y,x] = [1844,1983] with a side length of 228 pixels
# create_donut_stamps_for_cwfs completed
# Starting CWFS algorithm calculation.
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients [nm]: [-22.2, 43.0, 30.8, ]
# De-rotated [coma-X, coma-Y, focus]  zernike coefficients [nm]: [-47.7, -8.2, 30.8, ]
# Hexapod [x, y, z] offsets [mm] : -0.232, 0.040, 0.008,
# Telescope offsets [arcsec]: -12.1, 2.0, 0.0,
# ==============================
#
# Applying offset: x=-0.2315861268164377, y=0.040010763693954905, z=0.008380768605058847.
# Applying telescope offset az/el: 2.0192632221065163/-12.148776626663507.
# Calculating Az/El offset: 2.0192632221065163/-12.148776626663507
# Persistent x/y offset: -10.941673566608085/-5.6524310740165085
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done
# CWFS iteration 2 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# imagetype: ENGTEST, skip TCS synchronization.
# ENGTEST 0001 - 0001
# Moving to extra-focal position
# Taking extra-focal image
# imagetype: ENGTEST, skip TCS synchronization.
# ENGTEST 0001 - 0001
# intraImage expId for target: 2022021600273
# extraImage expId for target: 2022021600274
# angle used in cwfs algorithm is -71.10
# Moving hexapod back to zero offset (in-focus) position
# Running source detection
# Source detection completed
# Creating stamp for intra_image donut on centroid [y,x] = [1808,1968] with a side length of 228 pixels
# Creating stamp for intra_image donut on centroid [y,x] = [1829,1974] with a side length of 228 pixels
# create_donut_stamps_for_cwfs completed
# Starting CWFS algorithm calculation.
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients [nm]: [-12.0, 4.8, 14.5, ]
# De-rotated [coma-X, coma-Y, focus]  zernike coefficients [nm]: [-8.4, -9.8, 14.5, ]
# Hexapod [x, y, z] offsets [mm] : -0.041, 0.048, 0.005,
# Telescope offsets [arcsec]: -2.1, 2.4, 0.0,
# ==============================
#
# Focus (0.005) and coma (0.063) offsets inside tolerance level (0.010). Total focus correction: 0.013 mm. Total coma-x correction: -0.232 mm. Total coma-y correction: 0.040 mm.
# Applying telescope offset [az,el]: [2.403, -2.136].
# Calculating Az/El offset: 2.4034090061332867/-2.1355602870623107
# Persistent x/y offset: -1.2201637620247678/-2.9745912297796178
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done
# Hexapod LUT Datapoint - HD  73416 - reported hexapod position is, [-3.89622124046, 2.24631436419, -1.1676952445, 0.349999784133, 0.219997930559, -1.57931798555e-06].
# Taking in focus image after applying final results.
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# latiss_cwfs_align script completed successfully!
#
# Setting final state to <ScriptState.DONE: 8>
# Beginning target acquisition
# Performing blind offset set to False
# Using slew_icrs (object coordinate designation)
# Setting rotator position with respect to parallactic angle to 0.0 deg.
# Parallactic angle: -159.01247506121902 | Sky Angle: -69.01247506121902
# Sending command
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# Wait for ATMCS in position event.
# ATMCS in position: True.
# ATMCS already in position. Handling potential race condition.
# Dome following enabled. Waiting for dome to get in position.
# ATMCS in position: False.
# [Telescope] delta Alt = +000.085 deg; delta Az = +003.077 deg; delta N1 = -000.000 deg; delta N2 = +159.444 deg [Dome] delta Az = +002.938 deg
# ATDome in position.
# [Telescope] delta Alt = -000.000 deg; delta Az = +001.503 deg; delta N1 = -000.000 deg; delta N2 = +157.254 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.011 deg; delta N1 = +000.000 deg; delta N2 = +153.288 deg [Dome] delta Az = +002.938 deg
# Read historical data in 0.00 sec
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = -000.000 deg; delta N2 = +149.328 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = -000.000 deg; delta N2 = +145.343 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = -000.000 deg; delta N2 = +141.376 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.008 deg; delta N1 = -000.000 deg; delta N2 = +137.403 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +133.429 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = -000.000 deg; delta N2 = +129.457 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = -000.000 deg; delta N2 = +125.495 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = +000.000 deg; delta N2 = +121.523 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = +000.000 deg; delta N2 = +115.549 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = +000.000 deg; delta N2 = +111.590 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = -000.000 deg; delta N2 = +107.620 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = +000.000 deg; delta N2 = +103.645 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = -000.000 deg; delta N2 = +099.668 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +095.698 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +091.718 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = +000.000 deg; delta N2 = +087.752 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = -000.000 deg; delta N2 = +081.785 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = +000.000 deg; delta N2 = +075.826 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = +000.000 deg; delta N2 = +069.869 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.008 deg; delta N1 = -000.000 deg; delta N2 = +065.917 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.008 deg; delta N1 = +000.000 deg; delta N2 = +061.939 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +055.981 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +052.009 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +048.038 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +042.074 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +036.131 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +032.161 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = +000.000 deg; delta N2 = +026.188 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +020.290 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +014.696 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = +011.291 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = -000.000 deg; delta N2 = +006.852 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +004.492 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +001.847 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.005 deg; delta N1 = -000.000 deg; delta N2 = +000.808 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.008 deg; delta N1 = +000.000 deg; delta N2 = +000.068 deg [Dome] delta Az = +002.938 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.007 deg; delta N1 = +000.000 deg; delta N2 = -000.006 deg [Dome] delta Az = +002.938 deg
# ATMCS in position: True.
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 3
#
# Starting iteration number 1, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# seq_num 276 arrived in OODS
# Take Object returned [2022021600276]
# Now waiting for image to land in OODS
# Current brightest target position is (2475.1, 1576.7) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [69.38, 122.17] arcsec as calculated from sequence number 276 on Observation Day of 20220216
# Current radial pointing error of 140.49 arcsec exceeds the tolerance of 5 arcsec.
# Applying x/y offset to telescope pointing.
# Calculating x/y offset: 69.38236619952123/122.16548242537475
# Applying Az/El offset: 121.68424069539486/-70.2229549510288
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done
# At end of iteration loop, success is False. So moving to next iteration
#
# Starting iteration number 2, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# seq_num 277 arrived in OODS
# Take Object returned [2022021600277]
# Now waiting for image to land in OODS
# Current brightest target position is (1735.6, 314.68) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [-1.38, 1.40] arcsec as calculated from sequence number 277 on Observation Day of 20220216
# Acquisition completed successfully.Current radial pointing error of 1.97 arcsec is within the tolerance of 5 arcsec.
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Beginning taking data for target sequence
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 1 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 2 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started'].
# Ready to take data:: atmcs=False, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 3 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 4 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# Latiss_acquire_and_take_sequence script completed
#
# Setting final state to <ScriptState.DONE: 8>
# Beginning target acquisition
# Performing blind offset set to False
# Using slew_icrs (object coordinate designation)
# Setting rotator position with respect to parallactic angle to 0.0 deg.
# Parallactic angle: 108.36326572665234 | Sky Angle: -161.63673427334766
# Sending command
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# Wait for ATMCS in position event.
# ATMCS in position: True.
# ATMCS already in position. Handling potential race condition.
# Dome following enabled. Waiting for dome to get in position.
# ATMCS in position: False.
# [Telescope] delta Alt = -019.394 deg; delta Az = -109.794 deg; delta N1 = +000.000 deg; delta N2 = -022.223 deg [Dome] delta Az = -112.883 deg
# [Telescope] delta Alt = -019.237 deg; delta Az = -108.810 deg; delta N1 = -000.000 deg; delta N2 = -022.170 deg [Dome] delta Az = -112.443 deg
# [Telescope] delta Alt = -018.143 deg; delta Az = -104.965 deg; delta N1 = +000.000 deg; delta N2 = -021.406 deg [Dome] delta Az = -111.063 deg
# [Telescope] delta Alt = -017.109 deg; delta Az = -102.970 deg; delta N1 = +000.000 deg; delta N2 = -020.637 deg [Dome] delta Az = -109.803 deg
# [Telescope] delta Alt = -014.122 deg; delta Az = -098.973 deg; delta N1 = +000.000 deg; delta N2 = -018.220 deg [Dome] delta Az = -107.293 deg
# Read historical data in 0.00 sec
# [Telescope] delta Alt = -010.328 deg; delta Az = -094.977 deg; delta N1 = -000.000 deg; delta N2 = -014.862 deg [Dome] delta Az = -103.623 deg
# [Telescope] delta Alt = -006.416 deg; delta Az = -090.982 deg; delta N1 = -000.000 deg; delta N2 = -010.961 deg [Dome] delta Az = -099.063 deg
# [Telescope] delta Alt = -003.112 deg; delta Az = -086.986 deg; delta N1 = -000.000 deg; delta N2 = -007.084 deg [Dome] delta Az = -093.583 deg
# [Telescope] delta Alt = -000.958 deg; delta Az = -082.989 deg; delta N1 = -000.000 deg; delta N2 = -003.787 deg [Dome] delta Az = -087.913 deg
# [Telescope] delta Alt = -000.375 deg; delta Az = -080.993 deg; delta N1 = -000.000 deg; delta N2 = -002.492 deg [Dome] delta Az = -083.833 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -076.997 deg; delta N1 = -000.000 deg; delta N2 = -000.737 deg [Dome] delta Az = -076.993 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -073.000 deg; delta N1 = +000.000 deg; delta N2 = -000.064 deg [Dome] delta Az = -070.803 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -069.004 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -063.973 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -065.009 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -057.123 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -061.012 deg; delta N1 = +000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = -046.873 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -055.020 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -040.063 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -051.024 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -033.203 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -047.028 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -026.373 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -043.033 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -020.213 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -041.037 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = -016.113 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -037.039 deg; delta N1 = -000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = -005.853 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -031.045 deg; delta N1 = +000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = +001.507 deg
# ATDome in position.
# [Telescope] delta Alt = +000.002 deg; delta Az = -025.054 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -021.109 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -017.277 deg; delta N1 = +000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -011.936 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -008.783 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -006.053 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.003 deg; delta Az = -003.819 deg; delta N1 = -000.000 deg; delta N2 = +000.006 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.003 deg; delta Az = -001.478 deg; delta N1 = +000.000 deg; delta N2 = +000.006 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -000.305 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +003.007 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -000.037 deg; delta N1 = +000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = +003.007 deg
# ATMCS in position: True.
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 3
#
# Starting iteration number 1, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# Error in run
# Setting final state to <ScriptState.FAILED: 10>
# Beginning target acquisition
# Performing blind offset set to False
# Using slew_icrs (object coordinate designation)
# Setting rotator position with respect to parallactic angle to 0.0 deg.
# Parallactic angle: 107.11385608422037 | Sky Angle: -162.8861439157796
# Sending command
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# Wait for ATMCS in position event.
# ATMCS in position: True.
# ATMCS already in position. Handling potential race condition.
# Dome following enabled. Waiting for dome to get in position.
# ATMCS in position: False.
# [Telescope] delta Alt = -011.297 deg; delta Az = -009.679 deg; delta N1 = -000.000 deg; delta N2 = -011.276 deg [Dome] delta Az = -007.077 deg
# [Telescope] delta Alt = -010.345 deg; delta Az = -008.670 deg; delta N1 = -000.000 deg; delta N2 = -010.501 deg [Dome] delta Az = -006.267 deg
# [Telescope] delta Alt = -007.335 deg; delta Az = -005.372 deg; delta N1 = -000.000 deg; delta N2 = -007.650 deg [Dome] delta Az = -004.597 deg
# ATDome in position.
# Read historical data in 0.00 sec
# [Telescope] delta Alt = -003.453 deg; delta Az = -001.703 deg; delta N1 = +000.000 deg; delta N2 = -002.084 deg [Dome] delta Az = -002.977 deg
# [Telescope] delta Alt = -000.126 deg; delta Az = -000.001 deg; delta N1 = -000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = -001.257 deg
# ATMCS in position: True.
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 3
#
# Starting iteration number 1, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# seq_num 284 arrived in OODS
# Take Object returned [2022021600284]
# Now waiting for image to land in OODS
# Current brightest target position is (2244.9, 1794.1) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [47.36, 142.97] arcsec as calculated from sequence number 284 on Observation Day of 20220216
# Current radial pointing error of 150.61 arcsec exceeds the tolerance of 5 arcsec.
# Applying x/y offset to telescope pointing.
# Calculating x/y offset: 47.361307569078654/142.9691280307931
# Applying Az/El offset: 142.93033135561922/-47.47826242725269
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done
# At end of iteration loop, success is False. So moving to next iteration
#
# Starting iteration number 2, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# seq_num 285 arrived in OODS
# Take Object returned [2022021600285]
# Now waiting for image to land in OODS
# Current brightest target position is (1731.8, 305.29) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [-1.74, 0.51] arcsec as calculated from sequence number 285 on Observation Day of 20220216
# Acquisition completed successfully.Current radial pointing error of 1.81 arcsec is within the tolerance of 5 arcsec.
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Beginning taking data for target sequence
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 1 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 2 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started'].
# Ready to take data:: atmcs=False, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 3 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 4 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# Latiss_acquire_and_take_sequence script completed
#
# Setting final state to <ScriptState.DONE: 8>
# Beginning target acquisition
# Performing blind offset set to False
# Using slew_icrs (object coordinate designation)
# Setting rotator position with respect to parallactic angle to 0.0 deg.
# Parallactic angle: -114.90075215982621 | Sky Angle: -24.900752159826197
# Sending command
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# Wait for ATMCS in position event.
# ATMCS in position: True.
# ATMCS already in position. Handling potential race condition.
# Dome following enabled. Waiting for dome to get in position.
# ATMCS in position: False.
# [Telescope] delta Alt = -013.956 deg; delta Az = -164.205 deg; delta N1 = +000.000 deg; delta N2 = -013.908 deg [Dome] delta Az = -164.473 deg
# [Telescope] delta Alt = -012.201 deg; delta Az = -168.373 deg; delta N1 = -000.000 deg; delta N2 = -012.518 deg [Dome] delta Az = -163.193 deg
# Read historical data in 0.00 sec
# [Telescope] delta Alt = -008.950 deg; delta Az = -172.378 deg; delta N1 = -000.000 deg; delta N2 = -009.428 deg [Dome] delta Az = -160.993 deg
# [Telescope] delta Alt = -005.009 deg; delta Az = -176.382 deg; delta N1 = +000.000 deg; delta N2 = -003.655 deg [Dome] delta Az = -156.383 deg
# [Telescope] delta Alt = -000.747 deg; delta Az = +177.613 deg; delta N1 = +000.000 deg; delta N2 = -000.300 deg [Dome] delta Az = -149.493 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +171.607 deg; delta N1 = -000.000 deg; delta N2 = -000.003 deg [Dome] delta Az = -140.603 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +165.601 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -133.773 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +161.598 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -126.913 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +157.594 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -120.063 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +153.590 deg; delta N1 = +000.000 deg; delta N2 = -000.004 deg [Dome] delta Az = -109.803 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +147.584 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -102.983 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +143.579 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -096.813 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +139.578 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = -089.923 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +135.572 deg; delta N1 = +000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = -083.093 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +131.569 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = -072.813 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +125.563 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -065.953 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +121.560 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -059.083 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +117.556 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -052.223 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +113.552 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -045.413 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +109.548 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -038.563 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +105.544 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -031.753 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +101.541 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -025.573 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +097.537 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = -015.303 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +091.531 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = -008.483 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +087.527 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = -001.863 deg
# ATDome in position.
# [Telescope] delta Alt = -000.002 deg; delta Az = +083.524 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +002.927 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +077.517 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +071.512 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +067.508 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +063.504 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +059.501 deg; delta N1 = -000.000 deg; delta N2 = -000.004 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +053.494 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +047.490 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +041.483 deg; delta N1 = +000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +037.479 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +033.475 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +029.469 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +025.467 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +021.504 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +017.649 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +013.987 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +009.058 deg; delta N1 = -000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +005.073 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +002.246 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +001.043 deg; delta N1 = +000.000 deg; delta N2 = -000.005 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +000.153 deg; delta N1 = -000.000 deg; delta N2 = -000.004 deg [Dome] delta Az = +003.047 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +003.047 deg
# ATMCS in position: True.
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 3
#
# Starting iteration number 1, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# seq_num 291 arrived in OODS
# Take Object returned [2022021600291]
# Now waiting for image to land in OODS
# Current brightest target position is (2425.6, 1595.6) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [64.64, 123.98] arcsec as calculated from sequence number 291 on Observation Day of 20220216
# Current radial pointing error of 139.82 arcsec exceeds the tolerance of 5 arcsec.
# Applying x/y offset to telescope pointing.
# Calculating x/y offset: 64.6442015247154/123.97875343538723
# Applying Az/El offset: 124.21216223572928/-64.19457022899543
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done
# At end of iteration loop, success is False. So moving to next iteration
#
# Starting iteration number 2, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 12.0 seconds.
# seq_num 292 arrived in OODS
# Take Object returned [2022021600292]
# Now waiting for image to land in OODS
# Current brightest target position is (1735.3, 299.31) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [-1.41, -0.07] arcsec as calculated from sequence number 292 on Observation Day of 20220216
# Acquisition completed successfully.Current radial pointing error of 1.41 arcsec is within the tolerance of 5 arcsec.
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Beginning taking data for target sequence
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 1 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 2 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started'].
# Ready to take data:: atmcs=False, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 3 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 4 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# Latiss_acquire_and_take_sequence script completed
#
# Setting final state to <ScriptState.DONE: 8>
# Beginning target acquisition
# Performing blind offset set to False
# Using slew_icrs (object coordinate designation)
# Setting rotator position with respect to parallactic angle to 0.0 deg.
# Parallactic angle: 50.47308879050178 | Sky Angle: -219.52691120949822
# Sending command
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# Wait for ATMCS in position event.
# ATMCS in position: True.
# ATMCS already in position. Handling potential race condition.
# Dome following enabled. Waiting for dome to get in position.
# ATMCS in position: False.
# [Telescope] delta Alt = +017.591 deg; delta Az = +106.201 deg; delta N1 = +000.000 deg; delta N2 = +018.102 deg [Dome] delta Az = +108.557 deg
# [Telescope] delta Alt = +017.167 deg; delta Az = +104.278 deg; delta N1 = +000.000 deg; delta N2 = +017.764 deg [Dome] delta Az = +107.847 deg
# [Telescope] delta Alt = +015.479 deg; delta Az = +100.291 deg; delta N1 = +000.000 deg; delta N2 = +016.250 deg [Dome] delta Az = +106.197 deg
# Read historical data in 0.00 sec
# [Telescope] delta Alt = +014.096 deg; delta Az = +098.295 deg; delta N1 = +000.000 deg; delta N2 = +014.946 deg [Dome] delta Az = +104.747 deg
# [Telescope] delta Alt = +010.538 deg; delta Az = +094.296 deg; delta N1 = -000.000 deg; delta N2 = +011.523 deg [Dome] delta Az = +101.997 deg
# [Telescope] delta Alt = +006.578 deg; delta Az = +090.299 deg; delta N1 = +000.000 deg; delta N2 = +007.565 deg [Dome] delta Az = +098.487 deg
# [Telescope] delta Alt = +004.739 deg; delta Az = +088.303 deg; delta N1 = +000.000 deg; delta N2 = +005.648 deg [Dome] delta Az = +095.767 deg
# [Telescope] delta Alt = +003.127 deg; delta Az = +086.305 deg; delta N1 = +000.000 deg; delta N2 = +003.913 deg [Dome] delta Az = +092.717 deg
# [Telescope] delta Alt = +000.886 deg; delta Az = +082.306 deg; delta N1 = -000.000 deg; delta N2 = +001.334 deg [Dome] delta Az = +086.277 deg
# [Telescope] delta Alt = +000.049 deg; delta Az = +078.309 deg; delta N1 = +000.000 deg; delta N2 = +000.161 deg [Dome] delta Az = +079.577 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +076.313 deg; delta N1 = -000.000 deg; delta N2 = +000.006 deg [Dome] delta Az = +075.477 deg
# [Telescope] delta Alt = -000.003 deg; delta Az = +074.316 deg; delta N1 = -000.000 deg; delta N2 = -000.012 deg [Dome] delta Az = +071.367 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +070.317 deg; delta N1 = +000.000 deg; delta N2 = -000.004 deg [Dome] delta Az = +066.587 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = +066.319 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = +061.097 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +062.322 deg; delta N1 = +000.000 deg; delta N2 = +000.009 deg [Dome] delta Az = +050.847 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +056.327 deg; delta N1 = +000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = +044.007 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +052.331 deg; delta N1 = +000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = +037.147 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +048.334 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +030.297 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = +044.336 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +024.127 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +040.339 deg; delta N1 = -000.000 deg; delta N2 = +000.010 deg [Dome] delta Az = +013.867 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +034.344 deg; delta N1 = -000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = +007.047 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +030.347 deg; delta N1 = -000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = +000.767 deg
# ATDome in position.
# [Telescope] delta Alt = +000.001 deg; delta Az = +026.348 deg; delta N1 = -000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = -002.503 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +022.380 deg; delta N1 = -000.000 deg; delta N2 = +000.009 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +016.624 deg; delta N1 = -000.000 deg; delta N2 = +000.003 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +013.037 deg; delta N1 = -000.000 deg; delta N2 = +000.009 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +008.268 deg; delta N1 = +000.000 deg; delta N2 = +000.009 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +004.485 deg; delta N1 = -000.000 deg; delta N2 = +000.010 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +001.879 deg; delta N1 = +000.000 deg; delta N2 = +000.010 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +000.468 deg; delta N1 = -000.000 deg; delta N2 = +000.009 deg [Dome] delta Az = -002.993 deg
# [Telescope] delta Alt = +000.001 deg; delta Az = +000.021 deg; delta N1 = +000.000 deg; delta N2 = +000.009 deg [Dome] delta Az = -002.993 deg
# ATMCS in position: True.
# ...
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 3 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 4 of 4. Exptime =   20.0s, filter=empty_1, grating=holo4_003)
# Latiss_acquire_and_take_sequence script completed
#
# Setting final state to <ScriptState.DONE: 8>
# Beginning target acquisition
# Performing blind offset set to False
# Using slew_icrs (object coordinate designation)
# Setting rotator position with respect to parallactic angle to 0.0 deg.
# Parallactic angle: 122.15803215888808 | Sky Angle: -147.8419678411119
# Sending command
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# Wait for ATMCS in position event.
# ATMCS in position: True.
# ATMCS already in position. Handling potential race condition.
# Dome following enabled. Waiting for dome to get in position.
# ATMCS in position: False.
# [Telescope] delta Alt = +009.591 deg; delta Az = +064.255 deg; delta N1 = -000.000 deg; delta N2 = +010.310 deg [Dome] delta Az = +061.439 deg
# [Telescope] delta Alt = +008.417 deg; delta Az = +066.615 deg; delta N1 = +000.000 deg; delta N2 = +009.277 deg [Dome] delta Az = +060.589 deg
# [Telescope] delta Alt = +004.982 deg; delta Az = +070.601 deg; delta N1 = +000.000 deg; delta N2 = +006.055 deg [Dome] delta Az = +059.069 deg
# Read historical data in 0.00 sec
# [Telescope] delta Alt = +001.421 deg; delta Az = +074.594 deg; delta N1 = -000.000 deg; delta N2 = +000.933 deg [Dome] delta Az = +054.539 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +080.579 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = +048.689 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +086.568 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = +043.429 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +090.560 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +033.899 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +096.548 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = +027.059 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +100.538 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = +020.889 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +104.531 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +014.039 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +108.522 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +003.799 deg
# ATDome in position.
# [Telescope] delta Alt = +000.002 deg; delta Az = +114.510 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -001.201 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +118.502 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.041 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +122.493 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +126.485 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +132.472 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +136.464 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +142.450 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +146.442 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +150.436 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +154.427 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +158.417 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +162.411 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +166.401 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +172.391 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = +176.380 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -179.629 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = -177.636 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -173.640 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -169.648 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -163.660 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -159.670 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -153.680 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -147.695 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.003 deg; delta Az = -143.701 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -139.712 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -135.718 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -129.730 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -123.744 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -119.751 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -115.761 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -109.772 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -103.786 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -099.793 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -095.801 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -089.814 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -085.821 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -081.831 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -075.842 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -071.852 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -065.863 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -061.871 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -057.881 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -053.888 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -049.897 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -045.905 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -039.917 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -035.925 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.003 deg; delta Az = -029.934 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -025.944 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -021.983 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -018.118 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -014.436 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -009.446 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -006.613 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -004.263 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -001.740 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -000.728 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -000.194 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# [Telescope] delta Alt = +000.002 deg; delta Az = -000.013 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -003.061 deg
# ATMCS in position: True.
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 3
#
# Starting iteration number 1, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 22.0 seconds.
# seq_num 480 arrived in OODS
# Take Object returned [2022021600480]
# Now waiting for image to land in OODS
# Current brightest target position is (2044.6, 1632.4) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [28.19, 127.50] arcsec as calculated from sequence number 480 on Observation Day of 20220216
# Current radial pointing error of 130.58 arcsec exceeds the tolerance of 5 arcsec.
# Applying x/y offset to telescope pointing.
# Calculating x/y offset: 28.19308937677191/127.50001161437433
# Applying Az/El offset: 127.30483813842206/-29.06168331020074
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done
# At end of iteration loop, success is False. So moving to next iteration
#
# Starting iteration number 2, with a maximum of 3
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Waiting for image to arrive in OODS for a maximum of 22.0 seconds.
# seq_num 481 arrived in OODS
# Take Object returned [2022021600481]
# Now waiting for image to land in OODS
# Current brightest target position is (1734.8, 305.61) whereas the target position is (1750, 300)
# Calculated offsets [dx,dy] are [-1.45, 0.54] arcsec as calculated from sequence number 481 on Observation Day of 20220216
# Acquisition completed successfully.Current radial pointing error of 1.55 arcsec is within the tolerance of 5 arcsec.
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Beginning taking data for target sequence
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 1 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started', 'completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# Last correction completed.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# OBJECT 0001 - 0001
# Completed exposure 2 of 4. Exptime =   20.0s, filter=empty_1, grating=ronchi170lpmm)
# imagetype: OBJECT, wait for TCS to be ready.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['started'].
# Ready to take data:: atmcs=False, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.
# Received corrections: ['completed'].
# Ready to take data:: atmcs=True, ataos=False, atdome=True.
# atspectrograph correction running. Trying to determine state of the corrections.

# %%
# asyncio.get_event_loop().run_forever()

# %%
# How to write a message to the script

# %%
#logging.basicConfig(format="%(name)s:%(message)s", level=logging.DEBUG)

# %%
import numpy as np
import os

# %%
print(f'Your UID is {os.getuid()}')
index=os.getuid()*10+np.random.randint(0,9)
print(f'The generated index is {index}')

# %%
index <2147483647

# %%
c = salobj.Controller(name="Script", index=index)

# %%
c.

# %%
time.asctime()

# %%
# This goes to the EFD, but the controller by default is set to loglevel.info, so debug won't show unless you set the controller to do so
c.log.info(f'This is a test by Patrick from controller at INFO at time (from notebook)={time.asctime()}') # only

# %%
c.log.setLevel(logging.DEBUG)

# %%
c.log.debug(f'This is a test by Patrick from controller at DEBUG at time (from notebook)={time.asctime()}')

# %%
# This log message only appears in this notebook and does not go to the EFD
logging.info('This is a test by Patrick from logging.info')
logging.debug('This is a test by Patrick from logging.debug')
